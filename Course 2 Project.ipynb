# %%
#import libraries (pandas,mat,numpy,scikit)

# %%
# reading the data using pd

# %%
#EDA 
#generating distribution plots to understand the skewedness of different variables 
#or generating histograms to understand how data is distributed

# %% [markdown]
#  Explain whether the data needs to be cleaned based on your findings.

# %%
# data cleaning if needed

# %% [markdown]
# #selecting the type of machine learning model that is appropriate for predicting from your data.
# ### linear regression offers clear insights into the direction and magnitude of each variable’s impact,

# %%
# TTS
#.fit

# %%
#Evaluation(r2,mse)
#Explain what the measures tell us about the model and how it works.

# %% [markdown]
# Imagine a new scenario that requires a prediction from your model to answer. Describe the scenario in your post and run a prediction from the model. Explain the meaning of this prediction and what it tells a reader.
# نصيب الفرد من الناتج (GDP per capita)
# في سنة مستقبلية (مثلاً2025

# %% [markdown]
# عند تدريب نموذج Linear Regression
# على بيانات تاريخية، يتعلم النموذج أن
# عندما يرتفع التضخم أو مؤشر الأسعار، ماذا يحدث تقليديًا لـ GDP per capita
# عندما تزيد الصادرات كنسبة من الناتج، كيف يتغير نصيب الفرد
# عندما تزيد مشاركة القوى العاملة، كيف يؤثر ذلك على نصيب الفرد
# النموذج يأخذ هذه العلاقات ويشكّل دالة رياضية تربط بين المتغيرات المستقلة و المتغير التابع.
# بعدها، عندما تعطين النموذج قيم متوقعة لهذه المتغيرات في المستقبل (مثلاً التضخم = 3%، CPI = 108، الخ) … يقوم النموذج بحساب قيمة Y المتوقعة (GDP per capita) بناءً على العلاقات التي تعلمها.
